# %%
import ROOT
import uproot as ur
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

# %%
df = ROOT.RDataFrame("pulse", "/Users/dzenger/FCFD/data/out_run41.root")

# %%
h = df.Filter("(amp[6] < 50) && (amp[2] > 30)").Histo1D("LP2_50")
c1 = ROOT.TCanvas()
h.Draw()
c1.Draw()
# Out:
# <div id="root_plot_1755717160731" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1755717160731(Core) {
# ...

# %%
# %jsroot on
c1 = ROOT.TCanvas()
h.Draw()
c1.Draw()
# Out:
# <div id="root_plot_1755716609037" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1755716609037(Core) {
# ...

# %%
h2 = df.Filter("(amp[3] < 7)").Define("t", "(LP2_50[4] - LP2_50[0])*1e9").Histo1D(("", "histo", 25, 38, 39),"t")
c2 = ROOT.TCanvas()
h2.Draw()
c2.Draw()
# Out:
# <div id="root_plot_1755724876741" style="width: 700px; height: 500px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1755724876741(Core) {
# ...
